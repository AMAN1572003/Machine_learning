# %%
from __future__ import absolute_import,division,print_function,unicode_literals
import tensorflow as tf

# %%
mnist=tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test)= mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
x_train, x_test  =x_train/255.0, x_test/255.0

# %%
model=tf.keras.Sequential([
     tf.keras.layers.Flatten(input_shape=(28,28)),
     tf.keras.layers.Dense(125,activation='relu'),
     tf.keras.layers.Dropout(0.2),
     tf.keras.layers.Dense(10,activation='softmax')
])
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0659 - accuracy: 0.9793
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0588 - accuracy: 0.9807
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0522 - accuracy: 0.9825
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0479 - accuracy: 0.9840
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0442 - accuracy: 0.9854
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0423 - accuracy: 0.9859
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0388 - accuracy: 0.9869
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0359 - accuracy: 0.9879
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0364 - accuracy: 0.9876
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0319 - accuracy: 0.9889

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0718 - accuracy: 0.9811
# [0.07182977348566055, 0.9811000227928162]
